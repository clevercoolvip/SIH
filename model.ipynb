# %%
data = "data.xml"

# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse(data)

# %%
key = []
value = []
for i in tree.iter():
    print(str(i))
    key.append(str(i).split("'")[1])
    print(i.text)
    value.append(i.text)
    print("*"*120)
# Out:
# <Element 'breakfast_menu' at 0x000001B9C4D16900>
#
#
# ************************************************************************************************************************
# <Element 'food' at 0x000001B9C4D169F0>
#
#
# ************************************************************************************************************************
# <Element 'name' at 0x000001B9C4D169A0>
# Belgian Waffles
# ************************************************************************************************************************
# <Element 'price' at 0x000001B9C4D16A40>
# $5.95
# ************************************************************************************************************************
# <Element 'description' at 0x000001B9C4D16A90>
# Two of our famous Belgian Waffles with plenty of real maple syrup
# ************************************************************************************************************************
# <Element 'calories' at 0x000001B9C4D16AE0>
# 650
# ...

# %%
df = pd.DataFrame({"Key":key, "Values":value})

# %%
df
# Out:
#                Key                                             Values
# 0   breakfast_menu                                                 \n
# 1             food                                                 \n
# 2             name                                    Belgian Waffles
# 3            price                                              $5.95
# 4      description  Two of our famous Belgian Waffles with plenty ...
# 5         calories                                                650
# 6             food                                                 \n
# 7             name                         Strawberry Belgian Waffles
# 8            price                                              $7.95
# 9      description  Light Belgian waffles covered with strawberrie...
# 10        calories                                                900
# 11            food                                                 \n
# ...

# %%
df2 = df[df["Values"]!="\n"]
df2
# Out:
#             Key                                             Values
# 2          name                                    Belgian Waffles
# 3         price                                              $5.95
# 4   description  Two of our famous Belgian Waffles with plenty ...
# 5      calories                                                650
# 7          name                         Strawberry Belgian Waffles
# 8         price                                              $7.95
# 9   description  Light Belgian waffles covered with strawberrie...
# 10     calories                                                900
# 12         name                        Berry-Berry Belgian Waffles
# 13        price                                              $8.95
# 14  description  Light Belgian waffles covered with an assortme...
# 15     calories                                                900
# 17         name                                       French Toast
# ...
