# %%
data = "data.xml"

# %%
data = "datasets_test.xml"

# %%
data = "test2.xml"

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %%
tree = ET.parse(data)

# %%
key = []
value = []
for i in tree.iter():
    print(str(i))
    key.append(str(i).split("'")[1])
    print(i.text)
    value.append(i.text)
    print("*"*120)
# Out:
# <Element '{http://mehrbod.net/RR.xsd}Restaurant' at 0x00000241748E0130>
#
#
# ************************************************************************************************************************
# <Element 'Name' at 0x00000241748E0180>
# Staghorn Steakhouse
# ************************************************************************************************************************
# <Element 'ZipCode' at 0x00000241748E0220>
# 10018
# ************************************************************************************************************************
# <Element 'Cuisines' at 0x00000241748E0270>
# Seafood, Steakhouse
# ************************************************************************************************************************
# <Element 'PriceLevel' at 0x00000241748E0310>
#
# ************************************************************************************************************************
# <Element 'Hours' at 0x00000241748E0360>
#
# ...

# %%
df = pd.DataFrame({"Key":key, "Values":value})

# %%
df
# Out:
#                                       Key  \
# 0   {http://mehrbod.net/RR.xsd}Restaurant
# 1                                    Name
# 2                                 ZipCode
# 3                                Cuisines
# 4                              PriceLevel
# ..                                    ...
# 59                             TotalRated
# 60                                   Body
# 61                                 Rating
# 62                                   Pros
# 63                                   Cons
#
#                                                Values
# 0                                                  \n
# 1                                 Staghorn Steakhouse
# 2                                               10018
# 3                                 Seafood, Steakhouse
# 4
# ..                                                ...
# 59
# 60  I was at an event at the Garden and found Stag...
# 61                                                  5
# 62
# 63
# ...

# %%
df2 = df[df["Values"]!="\n"]
df2
# Out:
#                   Key                                             Values
# 1                Name                                Staghorn Steakhouse
# 2             ZipCode                                              10018
# 3            Cuisines                                Seafood, Steakhouse
# 4          PriceLevel
# 5               Hours
# 6             Payment
# 7           DressCode
# 9      SpecialFeature                                  Notable Wine List
# 10     SpecialFeature                                    Business Dining
# 11     SpecialFeature                                    Romantic Dining
# 12     SpecialFeature                                       Group Dining
# 13     SpecialFeature                                        Fine Dining
# 14      PromptSeating                                                yes
# 15    MakeReservation                                                yes
# 16           Romantic                                                yes
# ...

# %%
def xml2tables(path):
    import xml.etree.ElementTree as ET
    import pandas as pd
    tree = ET.parse(data)
    key = []
    value = []
    for i in tree.iter():
        print(str(i))
        key.append(str(i).split("'")[1])
        print(i.text)
        value.append(i.text)
        print("*"*120)
    df = pd.DataFrame({"Key":key, "Values":value})
    df2 = df[df["Values"]!="\n"]
    return df2

# %%
dataframe = xml2tables("data.xml")
# Out:
# <Element '{http://mehrbod.net/RR.xsd}Restaurant' at 0x0000024174884540>
#
#
# ************************************************************************************************************************
# <Element 'Name' at 0x0000024174884A40>
# Staghorn Steakhouse
# ************************************************************************************************************************
# <Element 'ZipCode' at 0x00000241748849F0>
# 10018
# ************************************************************************************************************************
# <Element 'Cuisines' at 0x0000024174884950>
# Seafood, Steakhouse
# ************************************************************************************************************************
# <Element 'PriceLevel' at 0x0000024174884090>
#
# ************************************************************************************************************************
# <Element 'Hours' at 0x0000024174884B80>
#
# ...

# %%
dataframe
# Out:
#                   Key                                             Values
# 1                Name                                Staghorn Steakhouse
# 2             ZipCode                                              10018
# 3            Cuisines                                Seafood, Steakhouse
# 4          PriceLevel
# 5               Hours
# 6             Payment
# 7           DressCode
# 9      SpecialFeature                                  Notable Wine List
# 10     SpecialFeature                                    Business Dining
# 11     SpecialFeature                                    Romantic Dining
# 12     SpecialFeature                                       Group Dining
# 13     SpecialFeature                                        Fine Dining
# 14      PromptSeating                                                yes
# 15    MakeReservation                                                yes
# 16           Romantic                                                yes
# ...
